# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
## Step1: Importing Necessary Libraries
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score, mean_squared_error

# %%
#https://drive.google.com/file/d/1eE2GQm7Kg1Dtco9zKOm33QWAsLr1_-jH/view?usp=sharing
train_data=pd.read_csv("train_ar.csv")
#https://drive.google.com/file/d/1uC-sfDRgU9ynYmvB6jCykJSEvQbGtfSJ/view?usp=sharing
test_data=pd.read_csv("test_ar.csv")

# %%
train_data.head()
# Out:
#           x          y
# 0 -3.000000   9.496714
# 1 -2.993994   8.825736
# 2 -2.987988   9.575761
# 3 -2.981982  10.415246
# 4 -2.975976   8.622280

# %%
test_data.head()
# Out:
#           x          y
# 0 -3.000000  10.399355
# 1 -2.979933   9.804635
# 2 -2.959866   8.820438
# 3 -2.939799   7.995483
# 4 -2.919732   9.223061

# %%
x_train=train_data["x"]
y_train=train_data["y"]
x_test=test_data["x"]
y_test=test_data["y"]## Step2: Data Loading

# %%
train_data.shape
# Out:
# (1000, 2)

# %%
test_data.shape
# Out:
# (300, 2)

# %% [markdown]
# Step 3 data processing & EDA

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(6, 4))
plt.scatter(x_train, y_train, color="blue", label="Data")
plt.show()

# %%
Step 4 based model
# Out:
#   Cell In[20], line 1
#     Step 4 based model
#          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
x_train = np.array(x_train).reshape(-1, 1)
x_test = np.array(x_test).reshape(-1, 1)

# %%
linear_model=LinearRegression()
linear_model.fit(x_train_data,y_train_data)
# Out:
# LinearRegression()

# %%
y_pred_linear_train = linear_model.predict(x_train)
y_pred_linear_test = linear_model.predict(x_test)

# %%
Step visulaisation of results
# Out:
#   Cell In[30], line 1
#     Step visulaisation of results
#                        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x_train, y_train, color="blue", label="Data")
plt.plot(x_train, y_pred_linear_train, color="red", label="Linear Regression", linewidth=2)
plt.title("Linear Regression on Nonlinear Data")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x_test, y_test, color="blue", label="Data")
plt.plot(x_test, y_pred_linear_test, color="red", label="Linear Regression", linewidth=2)
plt.title("Linear Regression on Nonlinear Data")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %%
Step 6 Evaluation
# Out:
#   Cell In[38], line 1
#     Step 6 Evaluation
#          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
r2_linear_train=r2_score(y_train_data, y_pred_linear_train)
r2_linear_test=r2_score(y_test_data, y_pred_linear_test)
mse_linear_train=mean_squared_error(y_train_data, y_pred_linear_train)
mse_linear_test=mean_squared_error(y_test_data, y_pred_linear_test)

print()
