# %% [markdown]
# ## Step1: Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Step2: Data Loading

# %%
#https://drive.google.com/file/d/1eE2GQm7Kg1Dtco9zKOm33QWAsLr1_-jH/view?usp=sharing
train_data=pd.read_csv("train_ar.csv")
#https://drive.google.com/file/d/1uC-sfDRgU9ynYmvB6jCykJSEvQbGtfSJ/view?usp=sharing
test_data=pd.read_csv("test_ar.csv")

# %%
train_data.head()
# Out:
#           x          y
# 0 -3.000000   9.496714
# 1 -2.993994   8.825736
# 2 -2.987988   9.575761
# 3 -2.981982  10.415246
# 4 -2.975976   8.622280

# %%
test_data.head()
# Out:
#           x          y
# 0 -3.000000  10.399355
# 1 -2.979933   9.804635
# 2 -2.959866   8.820438
# 3 -2.939799   7.995483
# 4 -2.919732   9.223061

# %%
train_data.shape
# Out:
# (1000, 2)

# %%
test_data.shape
# Out:
# (300, 2)

# %%
x_train=train_data["x"]
y_train=train_data["y"]
x_test=test_data["x"]
y_test=test_data["y"]## Step2: Data Loading

# %% [markdown]
# ## Step3: Data Processing & EDA

# %%
plt.figure(figsize=(6, 4))
plt.scatter(x_train, y_train, color="blue", label="Data")
plt.show()

# %% [markdown]
# ## Step4: Base Model

# %%
x_train = np.array(x_train).reshape(-1, 1)
x_test = np.array(x_test).reshape(-1, 1)

# %%
linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_linear_train = linear_model.predict(x_train)
y_pred_linear_test = linear_model.predict(x_test)

# %% [markdown]
# ## Step5: Visualisations of Results

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x_train, y_train, color="blue", label="Data")
plt.plot(x_train, y_pred_linear_train, color="red", label="Linear Regression", linewidth=2)
plt.title("Linear Regression on Nonlinear Data")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x_test, y_test, color="blue", label="Data")
plt.plot(x_test, y_pred_linear_test, color="red", label="Linear Regression", linewidth=2)
plt.title("Linear Regression on Nonlinear Data")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %% [markdown]
# ## Step6: Evaluation

# %%
r2_linear_train = r2_score(y_train, y_pred_linear_train)
r2_linear_test = r2_score(y_test, y_pred_linear_test)
mse_linear_train = mean_squared_error(y_train, y_pred_linear_train)
mse_linear_test = mean_squared_error(y_test, y_pred_linear_test)
print("Train and Test Performance:")
print(f"R-squared for Linear Regression (Train): {r2_linear_train:.5f}")
print(f"R-squared for Linear Regression (Test): {r2_linear_test:.5f}")
print(f"MSE for Linear Regression (Train): {mse_linear_train:.5f}")
print(f"MSE for Linear Regression (Test): {mse_linear_test:.5f}")
# Out:
# Train and Test Performance:
# R-squared for Linear Regression (Train): 0.00015
# R-squared for Linear Regression (Test): -0.00188
# MSE for Linear Regression (Train): 8.24055
# MSE for Linear Regression (Test): 8.60524

# %% [markdown]
# ## Step7: Experimenting with 2nd degree polynomial features

# %%
polynomial_model_deg2 = make_pipeline(PolynomialFeatures(degree=2), LinearRegression())
polynomial_model_deg2.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures()),
#                 ('linearregression', LinearRegression())])

# %%
y_pred_poly_deg2_train = polynomial_model_deg2.predict(x_train)
y_pred_poly_deg2_test = polynomial_model_deg2.predict(x_test)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x_train, y_train, color="lightblue", label="Data")
plt.plot(x_train, y_pred_poly_deg2_train, color="purple", label="Polynomial Regression (Degree 2)", linewidth=2)
plt.title("Polynomial Regression (Degree 2) on Nonlinear Data")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x_test, y_test, color="lightblue", label="Data")
plt.plot(x_test, y_pred_poly_deg2_test, color="purple", label="Polynomial Regression (Degree 2)", linewidth=2)
plt.title("Polynomial Regression (Degree 2) on Nonlinear Data")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %%
r2_poly_deg2_train = r2_score(y_train, y_pred_poly_deg2_train)
r2_poly_deg2_test = r2_score(y_test, y_pred_poly_deg2_test)
mse_poly_deg2_train = mean_squared_error(y_train, y_pred_poly_deg2_train)
mse_poly_deg2_test = mean_squared_error(y_test, y_pred_poly_deg2_test)
print("Train and Test Performance:")
print(f"R-squared for Polynomial Regression (Degree 2, Train): {r2_poly_deg2_train:.5f}")
print(f"R-squared for Polynomial Regression (Degree 2, Test): {r2_poly_deg2_test:.5f}")
print(f"MSE for Polynomial Regression (Degree 2, Train): {mse_poly_deg2_train:.5f}")
print(f"MSE for Polynomial Regression (Degree 2, Test): {mse_poly_deg2_test:.5f}")
# Out:
# Train and Test Performance:
# R-squared for Polynomial Regression (Degree 2, Train): 0.88393
# R-squared for Polynomial Regression (Degree 2, Test): 0.87786
# MSE for Polynomial Regression (Degree 2, Train): 0.95659
# MSE for Polynomial Regression (Degree 2, Test): 1.04910

# %% [markdown]
# ## Step8: Experimenting with 3rd degree polynomial features

# %%
polynomial_model_deg3 = make_pipeline(PolynomialFeatures(degree=3), LinearRegression())
polynomial_model_deg3.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(degree=3)),
#                 ('linearregression', LinearRegression())])

# %%
y_pred_poly_deg3_train = polynomial_model_deg3.predict(x_train)
y_pred_poly_deg3_test = polynomial_model_deg3.predict(x_test)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x_train, y_train, color="lightblue", label="Data")
plt.plot(x_train, y_pred_poly_deg3_train, color="purple", label="Polynomial Regression (Degree 3)", linewidth=2)
plt.title("Polynomial Regression (Degree 3) on Nonlinear Data")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x_test, y_test, color="lightblue", label="Data")
plt.plot(x_test, y_pred_poly_deg3_test, color="purple", label="Polynomial Regression (Degree 3)", linewidth=2)
plt.title("Polynomial Regression (Degree 3) on Nonlinear Data")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %%
r2_poly_deg3_train = r2_score(y_train, y_pred_poly_deg3_train)
r2_poly_deg3_test = r2_score(y_test, y_pred_poly_deg3_test)
mse_poly_deg3_train = mean_squared_error(y_train, y_pred_poly_deg3_train)
mse_poly_deg3_test = mean_squared_error(y_test, y_pred_poly_deg3_test)
print("Train and Test Performance:")
print(f"R-squared for Polynomial Regression (Degree 3, Train): {r2_poly_deg3_train:.5f}")
print(f"R-squared for Polynomial Regression (Degree 3, Test): {r2_poly_deg3_test:.5f}")
print(f"MSE for Polynomial Regression (Degree 3, Train): {mse_poly_deg3_train:.5f}")
print(f"MSE for Polynomial Regression (Degree 3, Test): {mse_poly_deg3_test:.5f}")
# Out:
# Train and Test Performance:
# R-squared for Polynomial Regression (Degree 3, Train): 0.88402
# R-squared for Polynomial Regression (Degree 3, Test): 0.87767
# MSE for Polynomial Regression (Degree 3, Train): 0.95589
# MSE for Polynomial Regression (Degree 3, Test): 1.05073

# %% [markdown]
# ## Step9: Experimenting with 4th degree polynomial features

# %%
polynomial_model_deg4 = make_pipeline(PolynomialFeatures(degree=4), LinearRegression())
polynomial_model_deg4.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(degree=4)),
#                 ('linearregression', LinearRegression())])

# %%
y_pred_poly_deg4_train = polynomial_model_deg4.predict(x_train)
y_pred_poly_deg4_test = polynomial_model_deg4.predict(x_test)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x_train, y_train, color="lightblue", label="Data")
plt.plot(x_train, y_pred_poly_deg4_train, color="purple", label="Polynomial Regression (Degree 4)", linewidth=2)
plt.title("Polynomial Regression (Degree 4) on Nonlinear Data")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x_test, y_test, color="lightblue", label="Data")
plt.plot(x_test, y_pred_poly_deg4_test, color="purple", label="Polynomial Regression (Degree 4)", linewidth=2)
plt.title("Polynomial Regression (Degree 4) on Nonlinear Data")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %%
r2_poly_deg4_train = r2_score(y_train, y_pred_poly_deg4_train)
r2_poly_deg4_test = r2_score(y_test, y_pred_poly_deg4_test)
mse_poly_deg4_train = mean_squared_error(y_train, y_pred_poly_deg4_train)
mse_poly_deg4_test = mean_squared_error(y_test, y_pred_poly_deg4_test)
print("Train and Test Performance:")
print(f"R-squared for Polynomial Regression (Degree 4, Train): {r2_poly_deg4_train:.5f}")
print(f"R-squared for Polynomial Regression (Degree 4, Test): {r2_poly_deg4_test:.5f}")
print(f"MSE for Polynomial Regression (Degree 4, Train): {mse_poly_deg4_train:.5f}")
print(f"MSE for Polynomial Regression (Degree 4, Test): {mse_poly_deg4_test:.5f}")
# Out:
# Train and Test Performance:
# R-squared for Polynomial Regression (Degree 4, Train): 0.88462
# R-squared for Polynomial Regression (Degree 4, Test): 0.87591
# MSE for Polynomial Regression (Degree 4, Train): 0.95092
# MSE for Polynomial Regression (Degree 4, Test): 1.06582

# %%
#2nd Degree Polynomial: 88.393-87.786 --> 0.60%
#3rd Degree Polynomial: 88.402-87.767 --> 0.64%
#4th Degree Polynomial: 88.462-87.591 --> 0.87%
# Out:
# 0.6069999999999993
